# %% [markdown]
# # Відповіді на запитання відкритого типу (ODQA або Open-domain question answering)
#
# У цій лабораторній роботі Ви познайомитеся із задачею відповіді на запитання відкритого типу. На відміну від стандартної задачі відповіді на запитання, для якої потребується і запитання і контекст з можливою відповіддю на поставлене запитання, відповідь на запитання відкритого типу потребує лише запитання.
# Задача ODQA є досить поширеною, а однією з її варіацій є функція Google Quick (Direct) Answer, що дозволяє отримувати швидкі відповіді на деякі запити прямо на сторінці пошукової видачі ще до переходу на інтернет-ресурс.

# %% [markdown]
# <center>
#     <figure>
#         <img src="https://www.rankranger.com/www-img/web/seo_glossary/google-quick-answer-example.jpg" alt ="Concrete">
#         <figcaption>
#             <a href="https://www.rankranger.com/www-img/web/seo_glossary/google-quick-answer-example.jpg">What is Google's Direct Answer?</a></figcaption>
#     </figure>
# </center>

# %% [markdown]
# ## Архітектура
#
# Існує декілька основних підходів до побудови ODQA-систем, дізнатися більше про які можна за [посиланням](https://lilianweng.github.io/posts/2020-10-29-odqa/).
# У рамках цієї роботи Ви побудуєте двоетапне рішення, що складається з пошуковика (**Retriever**) та читача (**Reader**).
# - **Retriever** для наданого запиту (запитання) "витягує" зі сховища даних з тисячами чи мільйонами записів релевантні документи, що найбільш ймовірно відповідають на поставлене запитання.
# - **Reader** у обраних релевантних документах намагається знайти сегменти (слова, словосполучення або речення), що містять повну відповідь на запитання.

# %% [markdown]
# <center>
#     <figure>
#         <img src="https://lilianweng.github.io/posts/2020-10-29-odqa/QA-retriever-reader.png" alt ="Concrete">
#         <figcaption>
#             <a href="https://lilianweng.github.io/posts/2020-10-29-odqa/QA-retriever-reader.png">How to Build an Open-Domain Question Answering System? by Lilian Weng</a></figcaption>
#     </figure>
# </center>

# %% [markdown]
# ## Підготовка середовища
#
# Процедури тренування моделей потребують значних обчислювальних ресурсів, тому для виконання лабораторної роботи бажано використовувати сервіси з доступом до GPU (Kaggle/Google Colab).

# %%
# Встановлення залежностей
# %pip install -U transformers
# %pip install -U datasets
# %pip install -U evaluate
# %pip install -U accelerate
# %pip install -U huggingface-hub
# %pip install -U sentence-transformers
# %pip install -U langchain
# %pip install -U langchain-community
# %pip install -U langchain-huggingface
# %pip install -U faiss-gpu

# %%
# виводить інформацію про графічний прискорювач та його поточне навантаження 
# !nvidia-smi
# Out:
# Sun Aug 11 21:20:00 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P0             25W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Імпорт бібліотек
import random

import torch
from transformers import pipeline, AutoTokenizer, DefaultDataCollator, AutoModelForQuestionAnswering, TrainingArguments, Trainer
from datasets import load_dataset, Dataset
from evaluate import load
from langchain.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings

# %%
# визначення обчислювального пристрою для роботи, cuda використовується для сеансу з обраним графічним прискорювачем
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ## 1. Підготовка даних
#
# У лабораторній роботі використовується [частково локалізована версія датасету SQuAD 2.0](https://huggingface.co/datasets/FIdo-AI/ua-squad), що містить тексти, запитання, а також розмічені сегменти у текстах, що є відповідями на запитання. Друга версія датасету відрізняється від першої тим, що деякі запитання можуть не мати відповіді.

# %%
# завантаження даних
qa_dataset = load_dataset("FIdo-AI/ua-squad")
qa_dataset, qa_dataset['train']['data'][:3]
# Out:
# Downloading readme:   0%|          | 0.00/3.12k [00:00<?, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# Downloading data:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# (DatasetDict({
#      train: Dataset({
#          features: ['version', 'data'],
#          num_rows: 13859
#      })
#  }),
#  [{'Answer': 'виготовлення продуктів та поширення досвіду, які люди хочуть отримати й можуть собі дозволити',
#    'Context': '5 січня 2012 року Вест оголосив про створення компанії для творчого контенту DONDA, названої на честь його покійної матері Донди Вест. Під час представлення Вест заявив, що компанія "продовжить там, де зупинився Стів Джобс"; DONDA діятиме як "дизайнерська компанія, яка забезпечить мислителям творчий простір для реалізації своїх мрій та ідей" з "метою виготовлення продуктів та поширення досвіду, які люди хочуть отримати й можуть собі дозволити". Вест, як відомо, мало говорить про діяльність компанії, відсутні як офіційний веб-сайт, так і представлення в соціальних мережах. Креативна філософія DONDA містить необхідність "розміщувати творців у спільному просторі разом із подібними думками", щоб "спростити та естетично вдосконалити все, що ми бачимо, смакуємо, торкаємось та відчуваємо". Сучасні критики відзначають незмінну мінімалістичну естетику, яка повторюється в багатьох творчих проектах DONDA.',
#    'Question': 'Якою була мета нової творчої компанії DONDA, створеної Каньє?'},
#   {'Answer': 'матері Донди Вест',
#    'Context': '5 січня 2012 року Вест оголосив про створення компанії для творчого контенту DONDA, названої на честь його покійної матері Донди Вест. Під час представлення Вест заявив, що компанія "продовжить там, де зупинився Стів Джобс"; DONDA діятиме як "дизайнерська компанія, яка забезпечить мислителям творчий простір для реалізації своїх мрій та ідей" з "метою виготовлення продуктів та поширення досвіду, які люди хочуть отримати й можуть собі дозволити". Вест, як відомо, мало говорить про діяльність компанії, відсутні як офіційний веб-сайт, так і представлення в соціальних мережах. Креативна філософія DONDA містить необхідність "розміщувати творців у спільному просторі разом із подібними думками", щоб "спростити та естетично вдосконалити все, що ми бачимо, смакуємо, торкаємось та відчуваємо". Сучасні критики відзначають незмінну мінімалістичну естетику, яка повторюється в багатьох творчих проектах DONDA.',
#    'Question': 'На честь кого названа творча компанія DONDA?'},
#   {'Answer': '5 січня 2012 року',
#    'Context': '5 січня 2012 року Вест оголосив про створення компанії для творчого контенту DONDA, названої на честь його покійної матері Донди Вест. Під час представлення Вест заявив, що компанія "продовжить там, де зупинився Стів Джобс"; DONDA діятиме як "дизайнерська компанія, яка забезпечить мислителям творчий простір для реалізації своїх мрій та ідей" з "метою виготовлення продуктів та поширення досвіду, які люди хочуть отримати й можуть собі дозволити". Вест, як відомо, мало говорить про діяльність компанії, відсутні як офіційний веб-сайт, так і представлення в соціальних мережах. Креативна філософія DONDA містить необхідність "розміщувати творців у спільному просторі разом із подібними думками", щоб "спростити та естетично вдосконалити все, що ми бачимо, смакуємо, торкаємось та відчуваємо". Сучасні критики відзначають незмінну мінімалістичну естетику, яка повторюється в багатьох творчих проектах DONDA.',
#    'Question': 'Коли Каньє публічно представив свою компанію DONDA?'}])

# %%
# детермінованість
random.seed(42)

# %%
# поділ датасету на тренувальний, валідаційний та тестовий набори
# для запобігання витоку тренувальних даних у валідаційний та тестовий набори
# необхідно ділити саме за контекстами, адже кожний текст може мати декілька запитань
def generate_split(qa_dataset) -> tuple:
    contexts = list(set([x['Context'] for x in qa_dataset['train']["data"]]))
    contexts.sort()
    random.shuffle(contexts)
    train_contexts, val_contexts, test_contexts = set(contexts[:2220]), set(contexts[2220:2420]), set(contexts[2420:])
    return train_contexts, val_contexts, test_contexts

def split_dataset(qa_dataset, train_contexts, val_contexts, test_contexts) -> tuple:
    train_rows, val_rows, test_rows = [], [], []
    for eid, row in enumerate(qa_dataset['train']['data']):
        # пошук індексу початку розміченої відповіді у контексті
        start_idx = row['Context'].find(row["Answer"])
        if start_idx == -1:
            # відповідь не знайдено у тексті (не повинно статися)
            print(row)
            continue
        example = {
            "answers": {"text": [row['Answer']], "answer_start": [start_idx]},
            "context": row['Context'],
            "id": str(eid),
            "question": row['Question']                   
        }
        if not row['Answer']:
            example['answers'] = {"text": [], "answer_start": []}
        if row['Context'] in train_contexts:
            train_rows.append(example)
        elif row['Context'] in val_contexts:
            val_rows.append(example)
        elif row['Context'] in test_contexts:
            test_rows.append(example)
    random.shuffle(train_rows)
    # опціонально, для випадкових прикладів під час виведення даних
    random.shuffle(val_rows)
    random.shuffle(test_rows)
    return train_rows, val_rows, test_rows

train_contexts, val_contexts, test_contexts = generate_split(qa_dataset)
print(len(train_contexts), len(val_contexts), len(test_contexts))

train_rows, val_rows, test_rows = split_dataset(qa_dataset, train_contexts, val_contexts, test_contexts)
len(train_rows), len(val_rows), len(test_rows)
# Out:
# 2220 200 200
# (11735, 1022, 1102)

# %%
train_rows[200:205]
# Out:
# [{'answers': {'text': ['В 1952 році'], 'answer_start': [0]},
#   'context': 'В 1952 році Королівською хартією університетський коледж в Хайфілді був модернізований до Саутгемптонського університету. Саутгемптон набув статусу міста, ставши the City of Southampton в 1964 році.',
#   'id': '12082',
#   'question': 'В якому році Королівська хартія дала назву Саутгемптонському університету?'},
#  {'answers': {'text': ['Бен Вестхофф'], 'answer_start': [760]},
#   'context': 'Вест є одним з найвідоміших творців ХХІ століття, за свої роботи він отримує схвалення від музичних критиків, шанувальників, колег-музикантів, художників та культурних діячів. Редактор "AllMusic" Джейсон Бірчмайер пише: "В міру того, як його кар\'єра просувалася на початку XXI століття, Вест зруйнував певні стереотипи щодо реперів і став суперзіркою на власних умовах, без пристосування своєї зовнішності, риторики чи музики під будь-які музичні стандарти". Джон Караманік з "New York Times" заявив, що Вест став "громовідводом для суперечок, вибуховою фігурою, яка може зарахувати до числа своїх досягнень увагу двох президентів, а також постійне представлення на нагородженнях та різних шоу (коли він відвідував їх)". Старший редактор "Village Voice Media" Бен Вестхофф охрестив його найважливішим виконавцем хіп-хопу всіх часів, написавши, що "він створив найкращі альбоми й найістотніше змінив музику, а його пісні, швидше за все, будуть популярними ще довгий час", тоді як "Complex" назвали його "найвидатнішим творцем ХХІ століття серед усіх видів мистецтва та усіх жанрів". "The Guardian" порівняли Веста з Девідом Боуї, стверджуючи, що "Вест продає більше платівок, ніж будь-хто інший (30-мільйонні продажі альбомів), і залишається при цьому неймовірно рішучим експериментатором, здатним впливати на культурну та політичну ситуації у світі".',
#   'id': '139',
#   'question': 'Хто сказав, що Каньє Вест був найважливішим виконавцем хіп-хопу всіх часів?'},
#  {'answers': {'text': [], 'answer_start': []},
#   'context': "Малочисельне населення Республіки Конго зосереджується в південно-західній частині країни, залишаючи величезні простори тропічних джунглів на півночі практично безлюдними. Таким чином, Конго є однією з найбільш урбанізованих країн Африки, де 70% усього населення проживає в кількох міських районах, а саме в Браззавілі, Пуент-Нуар або в одному з малих міст або сіл, що простягаються вздовж 534-кілометрової (332 милі) залізниці, яка з'єднує два міста. У сільській місцевості промислова та комерційна діяльність останніми роками стрімко знизилась, унаслідок чого сільські економіки залежали від уряду для підтримки та існування.",
#   'id': '2050',
#   'question': 'Яке з маленьких міст в Конго?'},
#  {'answers': {'text': ['близько 200 тис. робочих місць'],
#    'answer_start': [500]},
#   'context': 'За Троєцарства Нанкін був промисловим текстильним і карбувальним центром завдяки зручному географічному розташуванню та великій кількості транспортних шляхів. За часів правління династії Мін промисловість Нанкіна розвинулася ще дужче, і місто стало одним з найуспішніших у Китаї та світі. Воно мало пальму першості стосовно текстильної промисловості, карбування, поліграфії, суднобудування, і було найзначнішим діловим центром у Східній Азії. Текстиль палко розвивався за династії Цін: галузь надала близько 200 тис. робочих місць, а у 18 та 19 ст. у місті було 18 тис. атласних машин.',
#   'id': '9558',
#   'question': 'Скільки робочих місць було створено під час текстильного буму?'},
#  {'answers': {'text': ['iTunes'], 'answer_start': [450]},
#   'context': 'Виконання Девіда Арчулети твору Джона Леннона "Imagine" багато хто вважав одним із найкращих у сезоні. Дженніфер Лопес, яку призначили суддею в десятому сезоні, назвала цю пісню прекрасним моментом, який вона ніколи не забуде. Виступ у півфіналі Джейсона Кастро "Hallelujah" також здобув значну увагу, і він просунув версію пісні Джеффа Баклі до вершини цифрового пісенного чарту Billboard. Це був перший сезон, коли записи конкурсантів випустили на iTunes після їхніх виступів, і хоча звістки про продажі не оприлюднили, щоб не зашкодити конкурсу, інформація, що просочилася, вказувала на те, що пісні учасників часто потрапляли на перші місця у рейтингах продаж iTunes.',
#   'id': '863',
#   'question': 'Де вперше можна було придбати записи пісень учасника?'}]

# %% [markdown]
# ## 2. Побудова Reader-моделі
#
# Для вирішення задачі відповіді на запитання за контекстом буде використано мережу на базі архітектури кодуючого трансформера, принцип роботи якої полягає у наступному:
# - мережа отримує вхідну послідовність, що представляє собою запитання та контекст, розділені спеціальним токеном
# - мережа кодує отриману послідовність
# - доданий лінійний шар виконує декодування закодованої інформації шляхом оцінки імовірностей бути початком або кінцем сегменту відповіді для кожного токена (слова) з контексту
#
# Фактично, задача визначення сегменту у послідовності дуже схожа на стандартну задачу класифікації, але тут класифікується не уся послідовність, а кожний її елемент.
#
# [Детальніше про кодуючі трансформери](https://jalammar.github.io/illustrated-bert/)
#
# [Детальніше про вирішення задачі класифікації за допомогою кодуючих трансформерів](https://jalammar.github.io/a-visual-guide-to-using-bert-for-the-first-time/)

# %% [markdown]
# <center>
#     <figure>
#         <img src="https://mccormickml.com/assets/BERT/SQuAD/input_formatting.png?ref=blog.paperspace.com" alt ="Concrete">
#         <figcaption>
#             <a href="https://mccormickml.com/assets/BERT/SQuAD/input_formatting.png?ref=blog.paperspace.com">A Comparison of Question Answering Models by Abhijith Neil Abraham</a></figcaption>
#     </figure>
# </center>

# %% [markdown]
# <center>
#     <figure>
#         <img src="https://blog.paperspace.com/content/images/size/w1000/2020/08/BERT.jpg" alt ="Concrete">
#         <figcaption>
#             <a href="https://blog.paperspace.com/content/images/size/w1000/2020/08/BERT.jpg">BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding by Jacob Devlin</a></figcaption>
#     </figure>
# </center>

# %% [markdown]
# #### Варіанти для тренування моделі
#
# Варіант = Номер_у_списку % 2 + 1
#
# |**№**| Model                      | Epochs | Learning rate |
# |-----|----------------------------|--------|---------------|
# |**1**| microsoft/mdeberta-v3-base | 4      | 2e-05         |
# |**2**| microsoft/mdeberta-v3-base | 3      | 3e-05         |

# %%
model_name = "microsoft/mdeberta-v3-base"
# завантаження токенізатора
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
# опис параметрів https://github.com/huggingface/transformers/blob/v4.44.0/examples/pytorch/question-answering/run_qa.py#L105-L206

question_column_name = "question"
context_column_name = "context"
answer_column_name = "answers"
max_seq_length = 384
doc_stride = 128
pad_to_max_length = True
pad_on_right = tokenizer.padding_side == "right"

# підготовка даних для тренування
def prepare_train_features(examples):
    # У деяких питаннях зліва багато пробілів, що може спричинити помилки обрізання послідовностей,
    # тому ми їх видаляємо
    examples[question_column_name] = [q.lstrip() for q in examples[question_column_name]]

    tokenized_examples = tokenizer(
        examples[question_column_name if pad_on_right else context_column_name],
        examples[context_column_name if pad_on_right else question_column_name],
        truncation="only_second" if pad_on_right else "only_first",
        max_length=max_seq_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length" if pad_to_max_length else False,
    )

    # Оскільки один приклад з довгим контекстом може дати нам кілька ознак, 
    # нам потрібно мати зв'язок між ознакою та відповідним прикладом.
    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")
    offset_mapping = tokenized_examples.pop("offset_mapping")

    tokenized_examples["start_positions"] = []
    tokenized_examples["end_positions"] = []

    for i, offsets in enumerate(offset_mapping):
        # We will label impossible answers with the index of the CLS token.
        input_ids = tokenized_examples["input_ids"][i]
        if tokenizer.cls_token_id in input_ids:
            cls_index = input_ids.index(tokenizer.cls_token_id)
        elif tokenizer.bos_token_id in input_ids:
            cls_index = input_ids.index(tokenizer.bos_token_id)
        else:
            cls_index = 0

        # Отримуємо послідовність, що відповідає цьому прикладу
        sequence_ids = tokenized_examples.sequence_ids(i)

        # Один приклад може мати кілька сегментів
        # отримуємо індекс, що містить цей проміжок тексту.
        sample_index = sample_mapping[i]
        answers = examples[answer_column_name][sample_index]
        # Якщо запитання не має відповіді, то використовуємо спеціальний токен
        # у якості правильної відповіді
        if len(answers["answer_start"]) == 0:
            tokenized_examples["start_positions"].append(cls_index)
            tokenized_examples["end_positions"].append(cls_index)
        else:
            # Індекс початку та кінця відповіді в тексті
            start_char = answers["answer_start"][0]
            end_char = start_char + len(answers["text"][0])

            # Знаходження індексу початку поточного сегменту
            token_start_index = 0
            while sequence_ids[token_start_index] != (1 if pad_on_right else 0):
                token_start_index += 1

            # Знаходження індексу кінця поточного сегменту
            token_end_index = len(input_ids) - 1
            while sequence_ids[token_end_index] != (1 if pad_on_right else 0):
                token_end_index -= 1

            # Визначення того, чи входить розмічена відповідь у поточний сегмент
            if not (offsets[token_start_index][0] <= start_char and offsets[token_end_index][1] >= end_char):
                tokenized_examples["start_positions"].append(cls_index)
                tokenized_examples["end_positions"].append(cls_index)
            else:
                while token_start_index < len(offsets) and offsets[token_start_index][0] <= start_char:
                    token_start_index += 1
                tokenized_examples["start_positions"].append(token_start_index - 1)
                while offsets[token_end_index][1] >= end_char:
                    token_end_index -= 1
                tokenized_examples["end_positions"].append(token_end_index + 1)

    return tokenized_examples

# підготовка даних для тестування
def prepare_validation_features(examples):
    examples[question_column_name] = [q.lstrip() for q in examples[question_column_name]]

    tokenized_examples = tokenizer(
        examples[question_column_name if pad_on_right else context_column_name],
        examples[context_column_name if pad_on_right else question_column_name],
        truncation="only_second" if pad_on_right else "only_first",
        max_length=max_seq_length,
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length" if pad_to_max_length else False,
    )

    sample_mapping = tokenized_examples.pop("overflow_to_sample_mapping")

    tokenized_examples["example_id"] = []

    for i in range(len(tokenized_examples["input_ids"])):
        sequence_ids = tokenized_examples.sequence_ids(i)
        context_index = 1 if pad_on_right else 0

        sample_index = sample_mapping[i]
        tokenized_examples["example_id"].append(examples["id"][sample_index])

        tokenized_examples["offset_mapping"][i] = [
            (o if sequence_ids[k] == context_index else None)
            for k, o in enumerate(tokenized_examples["offset_mapping"][i])
        ]

    return tokenized_examples

# %%
train_set = Dataset.from_list(train_rows)
val_set = Dataset.from_list(val_rows)
test_set = Dataset.from_list(test_rows)
train_set, val_set, test_set
# Out:
# (Dataset({
#      features: ['answers', 'context', 'id', 'question'],
#      num_rows: 11735
#  }),
#  Dataset({
#      features: ['answers', 'context', 'id', 'question'],
#      num_rows: 1022
#  }),
#  Dataset({
#      features: ['answers', 'context', 'id', 'question'],
#      num_rows: 1102
#  }))

# %%
# підготовка даних для тренування та тестування
tokenized_train = train_set.map(prepare_train_features, batched=True, remove_columns=train_set.column_names)
tokenized_val = val_set.map(prepare_train_features, batched=True, remove_columns=val_set.column_names)
tokenized_test = test_set.map(prepare_validation_features, batched=True, remove_columns=test_set.column_names)

# %%
# завантаження моделі
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
# розміщення моделі на графічному прискорювачі
model.to(device)
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Some weights of DebertaV2ForQuestionAnswering were not initialized from the model checkpoint at microsoft/mdeberta-v3-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# конфігурація тренера
training_args = TrainingArguments(
    output_dir="deberta_squad_ukr_3epoch_16bs_3e05",
    eval_strategy="epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=16, # розмір пакету для тренування
    per_device_eval_batch_size=16, # розмір пакету для валідації
    num_train_epochs=3,
    weight_decay=0.01, # L2 регуляризація
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_val,
    tokenizer=tokenizer,
    data_collator=DefaultDataCollator(),
)

# тренування
# важливо: для запуску тренування у Kaggle необхідно виконати інструкції wandb, що будуть виведені на екран після запуску команди
trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb version 0.17.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.4
# Run data is saved locally in <code>/kaggle/working/wandb/run-20240811_212347-uhuo64t0</code>
# Syncing run <strong><a href='https://wandb.ai/nik-syromyatnikov-/huggingface/runs/uhuo64t0' target="_blank">xlmroberta_squad_ukr_4epoch_16bs_2e05</a></strong> to <a href='https://wandb.ai/nik-syromyatnikov-/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nik-syromyatnikov-/huggingface' target="_blank">https://wandb.ai/nik-syromyatnikov-/huggingface</a>
#  View run at <a href='https://wandb.ai/nik-syromyatnikov-/huggingface/runs/uhuo64t0' target="_blank">https://wandb.ai/nik-syromyatnikov-/huggingface/runs/uhuo64t0</a>
#     <div>
#
#       <progress value='2346' max='2346' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2346/2346 36:35, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.913500</td>
#       <td>1.070615</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.859400</td>
#       <td>0.966159</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.619700</td>
#       <td>1.044891</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2346, training_loss=1.0422585528829824, metrics={'train_runtime': 2303.366, 'train_samples_per_second': 16.294, 'train_steps_per_second': 1.019, 'total_flos': 7354983276794880.0, 'train_loss': 1.0422585528829824, 'epoch': 3.0})

# %%
# оцінка натренованої моделі
def evaluate_model(eval_set, model, tokenizer, device):
    model.to(device)
    pipe = pipeline("question-answering", model=model, tokenizer=tokenizer, device=device)
    # завантаження метрики, що використовується для оцінки передбачення
    squad_metric = load("squad_v2")

    # exact - точне співпадіння
    # f1 - середня оцінка F1 прогнозованих токенів відповіді у порівнянні із правильною відповіддю
    # детальніше про метрики: https://huggingface.co/spaces/evaluate-metric/squad_v2
    metrics = {"exact": [], "f1": [], "HasAns_f1": [], "HasAns_exact": [], "NoAns_f1": []}

    for idx, row in enumerate(eval_set):
        answer = pipe(question=row['question'], context=row['context'], handle_impossible_answer=True)
        # представлення правильної відповіді
        reference = {"answers": row['answers'], 'id': row['id']}
        # представлення передбаченої відповіді
        prediction = {"id": row['id'], "prediction_text": answer['answer'], "no_answer_probability": 0}
        results = squad_metric.compute(references=[reference], predictions=[prediction])
        # додаємо кожну метрику у список метрик
        for metric_key in metrics.keys():
            if not metric_key in results:
                continue
            metrics[metric_key].append(results[metric_key])
    
        if idx % 100 == 0:
            print(f"Processed {idx} examples")

    # обчислення середнього значення для кожної метрики
    return {key: sum(val) / len(val) if len(val) > 0 else 0 for key, val in metrics.items()}

evaluate_model(test_rows, model, tokenizer, device)
# Out:
# Downloading builder script:   0%|          | 0.00/6.47k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/11.3k [00:00<?, ?B/s]
# Processed 0 examples
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Processed 100 examples
# Processed 200 examples
# Processed 300 examples
# Processed 400 examples
# Processed 500 examples
# Processed 600 examples
# Processed 700 examples
# Processed 800 examples
# Processed 900 examples
# Processed 1000 examples
# Processed 1100 examples
# {'exact': 61.61524500907441,
#  'f1': 74.4583395208912,
#  'HasAns_f1': 75.42529825874239,
#  'HasAns_exact': 59.50506186726659,
#  'NoAns_f1': 70.4225352112676}

# %% [markdown]
# ## 3. Побудова Retriever-моделі
#
# Для побудови пошукової моделі скористаємося попередньо натренованою моделлю векторних представлень, що для кожної вхідної послідовності формує список чисел. При цьому близькі за сенсом послідовності будуть мати низьке значення для метрик дистанції (або високе для подібності).
#
# [Детальніше про векторні представлення](https://ai.gopubby.com/an-intuitive-101-guide-to-vector-embeddings-ffde295c3558)
#
# [Детальніше про семантичну подібність](https://www.sbert.net/docs/sentence_transformer/usage/semantic_textual_similarity.html)
#
# [Детальніше про семантичний пошук](https://www.sbert.net/examples/applications/semantic-search/README.html)
#
# [Детальніше про семантичний пошук з FAISS](https://huggingface.co/learn/nlp-course/en/chapter5/6)

# %%
# побудова сховища даних: збір усіх текстів з датасету
docs = list(set([x['Context'] for x in qa_dataset['train']['data']]))
len(docs), docs[:5]
# Out:
# (2620,
#  ['Струнні інструменти класичної епохи - це чотири інструменти, що утворюють струнну частину оркестру: скрипка, віола, віолончель та контрабас. Дерев’яні духові інструменти включали басет-кларнет, басетгорн, кларнет д’амур, класичний кларнет, шалюмо, флейту, гобой і фагот. Клавішні інструменти включали клавікорд та фортепіано. Хоча клавесин все ще використовувався в супроводі basso continuo в 1750-х і 1760-х роках, він вийшов з ужитку в кінці століття. Мідні духові інструменти включали buccin, офіклеїд (замінник серпенту, який був попередником туби) і рожок.',
#   'У 1968 році Шварценеггер та його колега-культурист Франко Колумбу почали цегляний бізнес. Бізнес процвітав завдяки маркетинговій кмітливості пари та підвищеному попиті після землетрусу в Сан-Фернандо 1971 року. Шварценеггер і Колумбу використали прибуток від цегляного цеху, щоб розпочати бізнес у сфері пошти, продаючи обладнання для бодібілдингу і фітнесу та навчальні записи.',
#   'Музика Шопена була використана в балеті "Шопініана" 1909 року, який хореографував Мішель Фокін та оркестрував Олександр Глазунов. Сергій Дягілєв замовив додаткові оркестрації від Стравінського, Анатолія Лядова, Сергія Танєєва та Миколи Черепніна для подальших постановок, які використовували назву Les Sylphides.',
#   "рідкіші ізотопи водню також мають своє конкретне застосування. Дейтерій (водень-2) використовується у програмах поділу ядер як сповільнювач для уповільнення нейтронів та у реакціях ядерного синтезу. З'єднання дейтерію мають застосування в хімії та біології для вивчення ефектів ізотопних реакцій. Тритій (водень-3), що виробляється в ядерних реакторах, використовується у виробництві водневих бомб як ізотопна мітка в біологічних науках і як джерело випромінювання у фарбах, що світяться.",
#   'Густа хвиля смогу з\'явилася в центральній та східній частині Китаю 2 грудня 2013 року на відстані близько 1200 кілометрів (750 миль), в таких містах як Тяньцзінь, Хебей, Шаньдун, Цзянсу, Аньхой, Шанхай та Чжецзян. Відсутність холодного повітряного потоку в поєднанні з повільними повітряними масами, що містять промислові викиди, утворила над регіоном товстий шар смогу. Смог сильно забруднював центральну та південну провінцію Цзянсу, особливо Нанкін та територію навколо, його індекс забруднення AQI був на рівні "сильно забруднений" протягом п\'яти днів поспіль та "дуже сильно забруднений" протягом дев\'яти. 3 грудня 2013 р. вміст твердих частинок PM2,5 в середньому перевищував 943 мкг на кубічний метр, і 4 грудня 2013 р. впав до понад 338 мкг на кубічний метр. Між 15:00, 3 грудня та 14:00, 4 грудня за місцевим часом , кілька швидкісних магістралей з Нанкіна до інших міст Цзянсу були закриті, через які десятки пасажирських автобусів потрапили на автовокзал Чжунцянмен. З 5 по 6 грудня Нанкін видав червоне попередження про забруднення повітря і закрив усі дитячі садочки та середні школи. Поліклінічні послуги дитячої лікарні зросли на 33 відсотки; загальна захворюваність на бронхіт, пневмонію, інфекції верхніх дихальних шляхів значно зросла. Смог розсіявся 12 грудня. Чиновники звинувачували в густому забрудненні відсутність вітру, викиди вихлопних газів автомобілів під низьким тиском повітря та систему централізованого теплопостачання на вугіллі в регіоні Північного Китаю. Вітри віднесли низько висячі повітряні маси заводських викидів (переважно SO2) до східного узбережжя Китаю.'])

# %%
# завантаження моделі векторного представлення
encoder = HuggingFaceEmbeddings(model_name="sentence-transformers/paraphrase-multilingual-mpnet-base-v2")

# побудова сховища даних: векторизація усіх текстів та організація їх швидкого пошуку
# за допомогою алгоритмів Facebook AI Similarity Search (FAISS)
db = FAISS.from_texts(texts=docs, embedding=encoder)

# %% [markdown]
# ## 4. ODQA: поєднання Retriever та Reader

# %%
def run_odqa(ranker, reader, query, k=10, handle_impossible_answer=True, threshold=0.5, return_all=False):
    # визначення K релевантних текстів для запиту
    docs_and_scores = ranker.similarity_search_with_score(query, k=k)
    query_answer = None
    answer_candidates = []
        
    for doc in docs_and_scores:
        context, retrieval_score = doc
        context = context.page_content
        # визначення сегменту-відповіді у кожному релевантному тексті
        # handle_impossible_answer=True - модель може передбачити відсутність відповіді у тексті
        answer = reader(question=query, context=context, handle_impossible_answer=handle_impossible_answer)
        qa_score = answer['score']
        answer_text = answer['answer']
        answer_candidate = (answer_text, qa_score, context)
        if return_all:
            # зберігаємо усі передбачення, щоб повернути K відповідей
            answer_candidates.append(answer_candidate)
        if qa_score < threshold:
            continue
        if query_answer is not None:
            # визначаємо відповідь з найбільшою ймовірністю
            if query_answer[1] >= qa_score or not answer_text:
                continue
        query_answer = answer_candidate
    return query_answer if not return_all else answer_candidates

# оцінка ефективності усього пайплайну: необхідно не лише отримати релевантний текст, але й знайти у ньому правильну відповідь
def eval_odqa(ranker, reader, test_set, k=10, handle_impossible_answer=True, threshold=0.5):
    results = []
    metrics = {"exact": [], "f1": [], "HasAns_f1": [], "HasAns_exact": [], "NoAns_f1": []}
    squad_metric = load("squad_v2")
    
    for row in test_set:
        query = row['question']
        query_answer = run_odqa(ranker, reader, query, k, handle_impossible_answer, threshold)
            
        reference = {"answers": row['answers'], 'id': row['id']}
        prediction = {"id": row['id'], "prediction_text": "", "no_answer_probability": 0}
        if query_answer is not None:
            prediction["prediction_text"] = query_answer[0]
        metric_scores = squad_metric.compute(references=[reference], predictions=[prediction])
        for metric_key in metrics.keys():
            if not metric_key in metric_scores:
                continue
            metrics[metric_key].append(metric_scores[metric_key])
        
        results.append({"predicted": query_answer, "truth": row})
    return results, {key: sum(val) / len(val) if len(val) > 0 else 0 for key, val in metrics.items()}

# %%
reader = pipeline("question-answering", model=model, tokenizer=tokenizer, device=device)

queries = [x['question'] for x in test_rows]
random.shuffle(queries)

# передбачення для 10 випадкових запитів
for query in queries[:10]:
    answer = run_odqa(db, reader, query, k=10, handle_impossible_answer=True, threshold=0.2)
    print(f"question: {query}\nanswer: {answer[0]}\nscore: {answer[1]}\ncontext: {answer[2]}\n\n")
# Out:
# question: Скільки людей за походженням з Пуерто-Рико в 2013 році проживало в Нью-Йорку?
# answer:  107 917.
# score: 0.5240135788917542
# context: У місті, особливо в районі Східного Бостона, є чисельна латиноамериканська громада. Латиноамериканці в Бостоні в основному складаються з пуерториканських (30 506 або 4,9% від загального населення міста), домініканських (25 648 або 4,2% від загального населення міста), сальвадорських (10850 або 1,8% від загального населення міста), колумбійських (6649 або 1,1% від загальної кількості міського населення), мексиканського (5961 або 1,0% від загального населення міста) та гватемальського (4451 або 0,7% від загального населення міста) етнічного походження. Загалом осіб латиноамериканського походження налічується 107 917. У Великому Бостоні ці цифри значно зростають: пуерториканців 175 000+, домініканців 95 000+, сальвадоран 40 000+, гватемальців 31 000+, мексиканців 25 000+ та колумбійців 22 000+.
#
#
# question: Коли розпочалось відродження класичного вчення?
# answer:  з 1400 року
# score: 0.5932994484901428
# context: У Європі епохи Відродження, починаючи приблизно з 1400 року відбувалося відродження класичного вчення, яке супроводжувалося розвитком гуманізму епохи Відродження, в якому ролі особистості в суспільстві приділялося більше уваги, ніж в Середньовіччі. Будинки приписувалися конкретним архітекторам - Брунеллески, Альберті, Мікеланджело, Палладіо - таким чином почав розвиватися культ особистості. У той час досі не розрізняли художника, архітектора, інженера та будь-кого іншого зі споріднених професій, таким чином назва часто залежала від регіональних вподобань.
#
#
# question: Що означає IALD?
# answer: Міжнародна асоціація дизайнерів світла
# score: 0.7601556181907654
# context: Міжнародна асоціація дизайнерів світла (IALD) - це організація, яка зосереджується на вдосконаленні освітлювальної галузі та визнанні незалежних професійних дизайнерів світла. Повністю незалежні дизайнери, які відповідають вимогам професійного членства в асоціації, зазвичай додають абревіатуру IALD до свого імені.
#
#
# question: Яке слово використовується у Франції для коміксів?
# answer:
# score: 0.9628183245658875
# context: Англійський термін комікси походить від гумористичного (або "комічного") твору, який переважав у ранніх американських газетних коміксах; використання цього терміну стало стандартним і для не жартівливих творів. Термін "комікс" має таку ж заплутану історію: вони найчастіше не гумористичні; вони не є звичайними книгами, а скоріше періодичними виданнями. В англійській мові часто трапляються комікси різних культур за термінами, що використовуються в їхніх оригінальних мовах, наприклад, манґа для японських коміксів, або bandes dessinees для франкомовних франко-бельгійських коміксів.
#
#
# question: Наскільки більшою була енергія цього землетрусу, ніж енергія, що виділилася під час землетрусу 1995 року в Японії?
# answer:  "у 25 разів більшим",
# score: 0.42518478631973267
# context: У статті Science висловлюється припущення, що будівництво та заповнення дамби Зіпінгпу могли спричинити землетрус. Головний інженер Сичуанського бюро геології та корисних копалин сказав, що раптовий перехід величезної кількості води в цей регіон міг послабити напругу між двома сторонами розлому, що б дозволило їм розійтися, могло збільшити прямий тиск на ній та викликати бурхливий розрив. Ефект був "у 25 разів більшим", ніж річний природний стрес від тектонічного руху. Уряд знехтував попередженнями про таку кількусть масштабних проектів дамб у сейсмічно активному районі. Дослідникам заборонено доступ до сейсмологічних та геологічних даних для подальшого вивчення причин землетрусу.
#
#
# question: Якого року місто було перейменовано на Бостон?
# answer:  1630 року
# score: 0.711009681224823
# context: Ранні європейські поселенці Бостона спочатку називали район Тримунтен (на честь "трьох гір" - наразі зберіглися лише їхні сліди), але згодом перейменували його в Бостон на честь Бостона, Лінкольншир, Англія - місце походження кількох видатних колоністів. Перейменування, 7 вересня 1630 року (за старим стилем), здійснили пуританські колоністи з Англії, які переїхали з Чарльзтауна на початку того року в пошуках прісної води. Спочатку їх поселення було обмежене півостровом Шоумут, на той час оточеним Массачусетською затокою та річкою Чарльз і пов’язаним з материком вузьким перешийком. Відомо, що півострів був заселений ще в 5000 р. до н. е.
#
#
# question: Яким був перший реліз Бекхема?
# answer:
# score: 0.9503949284553528
# context: Незважаючи на те, що він є оригінальною історією, "Спектр" спирається на вихідний матеріал Яна Флемінга, особливо в образі Франца Обергаузера, якого зіграв Крістоф Вальц. Обергаузер ділиться своїм ім'ям з Ганнесом Обергаузером, фоновим героєм роману "Восьминіжка" з колекції "Восьминіжка" та "Живі вогні", який у фільмі названий тимчасовим законним опікуном молодого Бонда в 1983 році. Показано, що Чарміан Бонд був його штатним опікуном, спостерігаючи за історією, створеною Флемінгом. З придбанням прав на "Спектр"  та пов'язаних з ним персонажів сценаристи Ніл Пурвіс та Роберт Вейд виявили, що фільм забезпечить незначне віддзеркалення безперервності попередніх фільмів, з організацією Квант, зазначеної в "Казино Рояль"  та представленої в "Кванті милосердя", де було переосмислення її як підрозділу в рамках Спектра, а не як незалежної організації.
#
#
# question: Яка релігійна теологія вплинула на ландшафтну архітектуру в Азії?
# answer:  пантеїстична
# score: 0.7903798818588257
# context: Архітектура різних куточків Азії розвивалась інакше ніж в Європі; буддистська, індуїстська та сикхська архітектури мають різні характеристики. Зокрема, буддистська архітектура продемонструвала значне регіональне різноманіття. Архітектура індуїсьських храмів, що склалася приблизно в 3 столітті до н. е., керується концепціями, викладеними в Шастрах, і виражає макрокосм та мікрокосм. У багатьох країнах Азії пантеїстична релігія спричинила появу архітектурних форм, які розроблялись спеціально для покращення природного ландшафту.
#
#
# question: За скільки домогосподарств відповідали офіцери Цяньху?
# answer:
# score: 0.8993850946426392
# context: І віце-король Цін, і король Тайпін мешкали у будівлях, які згодом отримали назву Президентський палац. Коли в 1864 році війська Цин під проводом Цзена Гуофана відвоювали місто, у місті відбулася масова різанина, за оцінками понад 100 000 осіб покінчили життя самогубством або боролися до смерті. З початку повстання Тайпін сили Цин не дозволили жодним повстанцям, що говорять на його діалекті, здатися. Ця політика масових вбивств мирних жителів відбулася в Нанкіні.
#
#
# question: Коли завоювання Тибету досягло свого піку?
# answer:  у 1642 році,
# score: 0.5347284078598022
# context: Колмаш пише, що по мірі збільшення присутності монголів у Тибеті, піком якого стало завоюванням Тибету монгольським лідером у 1642 році, імператори Мін "з очевидною безтурботністю розглядали ці події в Тибеті". Він додає, що відсутність турботи суду Мін про Тибет стала однією з причин, чому монголи скористались шансом повернути свого старого васала Тибету і "ще раз заповнити політичний вакуум у цій країні". Про масовий перехід монголів у тибетський буддизм за часів Алтан-хана Лейрд пише, що "китайці з цікавістю спостерігали за цим розвитком подій, хоча невелика кількість китайців стала побожними тибетськими буддистами".

# %%
# оцінка точності ODQA пайплайну на тестовому наборі
results, metrics = eval_odqa(db, reader, test_rows, k=5, threshold=0.0)

# %%
metrics
# Out:
# {'exact': 34.39201451905626,
#  'f1': 40.2248049093357,
#  'HasAns_f1': 31.63974691798422,
#  'HasAns_exact': 24.409448818897637,
#  'NoAns_f1': 76.05633802816901}

# %%
results[0:20]
# Out:
# [{'predicted': (' 1903 року,',
#    0.7248746156692505,
#    "Міст Джорджа Вашингтона - це найбільш завантажений у світі автомобільний міст, який з'єднує Манхеттен з округом Берген, штат Нью-Джерсі. Міст Верразано-Нероу - найдовший підвісний міст в Америці та один із найдовших у світі. Бруклінський міст - це ікона самого міста. Вежі Бруклінського мосту побудовані з вапняку, граніту та цементу Розендейл, а їх архітектурний стиль - неоготичний, з характерними загостреними арками над проходами крізь кам’яні вежі. Цей міст був також найдовшим підвісним мостом у світі з моменту його відкриття до 1903 року, і є першим підвісним мостом із сталевого дроту."),
#   'truth': {'answers': {'text': ['1903 року'], 'answer_start': [536]},
#    'context': "Міст Джорджа Вашингтона - це найбільш завантажений у світі автомобільний міст, який з'єднує Манхеттен з округом Берген, штат Нью-Джерсі. Міст Верразано-Нероу - найдовший підвісний міст в Америці та один із найдовших у світі. Бруклінський міст - це ікона самого міста. Вежі Бруклінського мосту побудовані з вапняку, граніту та цементу Розендейл, а їх архітектурний стиль - неоготичний, з характерними загостреними арками над проходами крізь кам’яні вежі. Цей міст був також найдовшим підвісним мостом у світі з моменту його відкриття до 1903 року, і є першим підвісним мостом із сталевого дроту.",
#    'id': '13480',
#    'question': 'Бруклінський міст був найбільшим у світі до якої дати?'}},
#  {'predicted': (' вздовж розлому Лонгменшань,',
#    0.7106371521949768,
#    'Згідно з дослідженням Управління землетрусів у Китаї (CEA), землетрус стався вздовж розлому Лонгменшань, геологічної конструкції вздовж кордону Індо-Австралійської та Євразійської плит. Сейсмічна діяльність була зосереджена на його середньому розломі(відомому як Іньсюй-Бейчуанський перелом). Розрив тривав близько 120 секунд, причому більша частина енергії виділялася в перші 80 секунд. Починаючи з Веньчуаня, розрив поширювався із середньою швидкістю 3,1 кілометра в секунду 49° на північний схід, загалом розриваючи близько 300 км. Максимальне зміщення становило 9 метрів. Фокус був глибше 10 км.'),
#   'truth': {'answers': {'text': ['сільській'], 'answer_start': [204]},
#    'context': 'Новини повідомляють, що найбільше постраждали бідні села. Свамінатан Кришнан, доцент кафедри цивільного будівництва та геофізики в Каліфорнійському технологічному інституті, зазначив: "землетрус стався у сільській частині Китаю. Імовірно, багато будівель були просто побудовані без попереднього проектування". Далі Сумінанат Кришнан додав: "У Китаї існують дуже суворі будівельні норми, які забезпечують безпеку з питань землетрусів та сейсмічного проектування. Але багато з цих будівель, мабуть, були досить старими і, ймовірно, не будувались з урахуванням будь-яких нормативних актів, що їх контролюють".',
#    'id': '11795',
#    'question': 'В якій частині Китаю стався землетрус?'}},
#  {'predicted': (' посилює конвекцію, створюючи такі атмосферні явища,',
#    0.1181001290678978,
#    'Сонячне випромінювання поглинається земною поверхнею Землі, океанами - які охоплюють близько 71% земної кулі - та атмосферою. Тепле повітря, що містить воду, яка випаровується з океанів, піднімається вгору, викликаючи циркуляцію або конвекцію атмосфери. Коли повітря досягає великої висоти, де температура низька, водяна пара конденсується в хмари, які випадають на поверхню Землі, завершуючи кругообіг води. Приховане тепло конденсації води посилює конвекцію, створюючи такі атмосферні явища, як вітер, циклони та антициклони. Сонячне світло, поглинене океанами та сушевими масами, підтримує поверхню при середній температурі 14°C. Фотосинтезом зелені рослини перетворюють сонячну енергію в хімічно накопичену енергію, яка виробляє їжу, деревину та біомасу, з якої отримують викопне паливо.'),
#   'truth': {'answers': {'text': ['Приховане тепло конденсації води посилює конвекцію'],
#     'answer_start': [409]},
#    'context': 'Сонячне випромінювання поглинається земною поверхнею Землі, океанами - які охоплюють близько 71% земної кулі - та атмосферою. Тепле повітря, що містить воду, яка випаровується з океанів, піднімається вгору, викликаючи циркуляцію або конвекцію атмосфери. Коли повітря досягає великої висоти, де температура низька, водяна пара конденсується в хмари, які випадають на поверхню Землі, завершуючи кругообіг води. Приховане тепло конденсації води посилює конвекцію, створюючи такі атмосферні явища, як вітер, циклони та антициклони. Сонячне світло, поглинене океанами та сушевими масами, підтримує поверхню при середній температурі 14°C. Фотосинтезом зелені рослини перетворюють сонячну енергію в хімічно накопичену енергію, яка виробляє їжу, деревину та біомасу, з якої отримують викопне паливо.',
#    'id': '13590',
#    'question': 'Що створює вітер, циклони та антициклони?'}},
#  {'predicted': (' Школи району',
#    0.4693335294723511,
#    'Бостонські коледжі та університети мають значний вплив на регіональну економіку. Бостон залучає понад 350 000 студентів з усього світу, які щороку вносять більше 4,8 мільярдів доларів в економіку міста. Школи району є основними роботодавцями та залучають фахівців до міста та прилеглої області. У місті базується низка технологічних компаній і центр біотехнологій. Інститут Мілкена, Бостон, визнаний найкращим кластером природничих наук в країні. Бостон отримує найбільший обсяг щорічного фінансування від Національного інституту охорони здоров’я з усіх міст Сполучених Штатів.'),
#   'truth': {'answers': {'text': ['Університет штату Меріленд'],
#     'answer_start': [264]},
#    'context': 'Через обмеженість у просторі NARA відкрила другу установу, відому неофіційно як Archives II, у 1994 році неподалік від Університету штату Меріленд, кампус Коледж-Парку (8601 Adelphi Road, College Park, MD, 20740-6001). Багато в чому завдяки цій близькості NARA та Університет штату Меріленд беруть участь у спільних ініціативах. Кампус Коледж-Парк включає археологічні розкопки, внесені до Національного реєстру історичних місць у 1996 році.',
#    'id': '8858',
#    'question': 'З яким коледжем NARA має ініціативи щодо кооперативів?'}},
#  {'predicted': (' 41,7 мільйона фунтів стерлінгів',
#    0.5356502532958984,
#    'У Сполученому Королівстві фільм зібрав 4,1 мільйона фунтів стерлінгів (6,4 мільйона доларів) за попередній показ у понеділок. У день відкриття він зібрав 6,3 мільйона фунтів стерлінгів (9,2 мільйона доларів), а потім у середу 5,7 мільйона фунтів стерлінгів (8,8 мільйона доларів), встановивши рекорди Великобританії за обидва дні. За перші сім днів фільм заробив 41,7 мільйона фунтів стерлінгів (63,8 мільйона доларів), побивши рекорд Великобританії за найвищий показник за перший тиждень, встановлений фільмом "Гаррі Поттером та в\'язень Азкабану" в 23,88 мільйона фунтів стерлінгів (36,9 мільйона доларів) у 2004 році. У п\'ятницю-суботу загальна сума склала 20,4 мільйона фунтів стерлінгів (31,2 мільйона доларів) у порівнянні з 20,1 мільйонами фунтів стерлінгів (31 мільйон доларів). Фільм також побив рекорд серед найкращих середніх показників екранних дебютів - 110 000 доларів, рекорд, який раніше мав фільм "Темний лицар", - 100 200 доларів. Там він загалом зібрав 136,3 мільйона доларів. У Великобританії він перевершив "Аватар" і став найбільш рентабельним релізом IMAX за всю історію - 10,09 млн доларів.'),
#   'truth': {'answers': {'text': ['41,7 мільйона фунтів стерлінгів (63,8 мільйона доларів)'],
#     'answer_start': [363]},
#    'context': 'У Сполученому Королівстві фільм зібрав 4,1 мільйона фунтів стерлінгів (6,4 мільйона доларів) за попередній показ у понеділок. У день відкриття він зібрав 6,3 мільйона фунтів стерлінгів (9,2 мільйона доларів), а потім у середу 5,7 мільйона фунтів стерлінгів (8,8 мільйона доларів), встановивши рекорди Великобританії за обидва дні. За перші сім днів фільм заробив 41,7 мільйона фунтів стерлінгів (63,8 мільйона доларів), побивши рекорд Великобританії за найвищий показник за перший тиждень, встановлений фільмом "Гаррі Поттером та в\'язень Азкабану" в 23,88 мільйона фунтів стерлінгів (36,9 мільйона доларів) у 2004 році. У п\'ятницю-суботу загальна сума склала 20,4 мільйона фунтів стерлінгів (31,2 мільйона доларів) у порівнянні з 20,1 мільйонами фунтів стерлінгів (31 мільйон доларів). Фільм також побив рекорд серед найкращих середніх показників екранних дебютів - 110 000 доларів, рекорд, який раніше мав фільм "Темний лицар", - 100 200 доларів. Там він загалом зібрав 136,3 мільйона доларів. У Великобританії він перевершив "Аватар" і став найбільш рентабельним релізом IMAX за всю історію - 10,09 млн доларів.',
#    'id': '9740',
#    'question': 'Скільки заробив "Спектр" за перший тиждень?'}},
#  {'predicted': (" Сак'ю Пандіту",
#    0.7574002146720886,
#    'монгольський принц Годан, онук Чингісхана, здійснив рейд аж до Лхаси. Під час нападу в 1240 р. Принц Годан викликав Сак\'ю Пандіту (1182–1251), лідера школи тибетського буддизму Сакя, до свого двору в теперішній Ганьсу в Західному Китаї. Під підпорядкуванням Сак\'ї Пандіти Годану в 1247 році Тибет був офіційно включений до складу Монгольської імперії під час регентства Терегена Хатуна (1241–1246). Майкл К. ван Уолт ван Прааг пише, що Годан наділив Сак\'ю Пандіту тимчасовою владою над все ще політично роздробленим Тибетом, заявляючи, що "ця інвестиція мала незначний реальний вплив", але вона мала значуще значення в тому, що вона встановила унікальний зв\'язок "священик-покровитель" між монголами і ламами Сак\'я.'),
#   'truth': {'answers': {'text': ["Сак'ї Пандіти Годану"],
#     'answer_start': [258]},
#    'context': 'монгольський принц Годан, онук Чингісхана, здійснив рейд аж до Лхаси. Під час нападу в 1240 р. Принц Годан викликав Сак\'ю Пандіту (1182–1251), лідера школи тибетського буддизму Сакя, до свого двору в теперішній Ганьсу в Західному Китаї. Під підпорядкуванням Сак\'ї Пандіти Годану в 1247 році Тибет був офіційно включений до складу Монгольської імперії під час регентства Терегена Хатуна (1241–1246). Майкл К. ван Уолт ван Прааг пише, що Годан наділив Сак\'ю Пандіту тимчасовою владою над все ще політично роздробленим Тибетом, заявляючи, що "ця інвестиція мала незначний реальний вплив", але вона мала значуще значення в тому, що вона встановила унікальний зв\'язок "священик-покровитель" між монголами і ламами Сак\'я.',
#    'id': '2542',
#    'question': "Хто був лідером школи тибетського буддизму Сак'я?"}},
#  {'predicted': (' соціальну поведінку,',
#    0.7699854969978333,
#    'Практика використання собак та інших тварин у терапії сягає кінця 18 століття, коли тварин вводили в психіатричні установи, щоби допомогти соціалізувати пацієнтів із психічними розладами. Дослідження показали, що терапія за допомогою собак може покращити соціальну поведінку, наприклад, люди з хворобою Альцгеймера починають посміхатися та сміятися. Одне дослідження продемонструвало, що діти із синдромом дефіциту уваги та гіперактивністю, а також із порушеннями поведінки, які брали участь у навчальній програмі із собаками та іншими тваринами, демонстрували більшу відвідуваність, підвищували цілі знань та навичок, а також знижували асоціальну та жорстоку поведінку, у порівнянні з тими, хто не брав участі в цій програмі.'),
#   'truth': {'answers': {'text': ['соціальних взаємодій'],
#     'answer_start': [600]},
#    'context': 'Користь для здоров’я людини може бути наслідком контакту із собаками загалом, а не лише наявності собак як домашніх тварин. Наприклад, за присутність собаки, у людей діагностується зниження серцево-судинних, поведінкових та психологічних показників тривожності. Інші переваги для здоров’я люди отримують через вплив імуностимулювальних мікроорганізмів, які, згідно з гігієнічною гіпотезою, можуть захистити від алергії та аутоімунних захворювань. Переваги контакту із собакою також включають соціальну підтримку, оскільки вони не лише здатні перебувати в стосунках із людьми, а й бути фасилітаторами соціальних взаємодій між людьми. Одне дослідження показало, що користувачі інвалідних візків відчувають більше позитивної соціальної взаємодії з незнайомцями, коли їх супроводжує собака, ніж коли тих немає. У 2015 році дослідження показало, що власники домашніх тварин мають набагато більше шансів познайомитись із людьми, зокрема сусідами, ніж власники без домашніх улюбленців.',
#    'id': '1455',
#    'question': 'Посередником чого можуть виступати собаки?'}},
#  {'predicted': ('',
#    0.9829617142677307,
#    "У галузі будівництва та забезпечення житлом існують численні можливості для відволікання уваги і отримання прибутку за рахунок неякісної роботи, відкатів за контрактами і фаворитизму при наданні цінних матеріалів для забезпечення житлом. Таким чином, в той час як гуманітарні організації, як правило, найбільше турбуються про відволікання допомоги в результаті включення занадто великого числа людей, самі одержувачі допомоги найбільше турбуються про відчуження. Доступ до допомоги може бути обмежений для тих, хто має зв'язки, для тих, хто платить хабарі або змушений надавати сексуальні послуги. Також ті, хто здатні це робити, можуть маніпулювати статистикою, щоб збільшити кількість бенефіціарів та вилучити додаткову допомогу."),
#   'truth': {'answers': {'text': [], 'answer_start': []},
#    'context': 'За словами Сунь Цзядуна, головного конструктора навігаційної системи, "Багато організацій вже давно використовують нашу систему, і це їм дуже подобається".',
#    'id': '6388',
#    'question': 'Хто цитує слова, що не багато організацій користуються системою?'}},
#  {'predicted': (' Плімута.',
#    0.9484534859657288,
#    'У місті 119 500 чоловіків та 117 400 жінок. Віковий діапазон 20–24 років є найбільш густонаселеним. За оцінками, 32 300 людей потрапляють у цей віковий діапазон. Наступним за величиною є діапазон 25–29 з 24 700 людьми, а потім 30–34 роки з 17 800. За чисельністю населення Саутгемптон є найбільшим моноцентричним містом у регіоні Південно-Східної Англії та другим за величиною на Південному узбережжі після Плімута.'),
#   'truth': {'answers': {'text': ['Лондона'], 'answer_start': [221]},
#    'context': 'У період з 1996 по 2004 рік населення міста збільшилось на 4,9 відсотка - десяте найбільше зростання в Англії. У 2005 році урядова статистика заявила, що Саутгемптон був третім найбільш густонаселеним містом країни після Лондона та Портсмута відповідно. Рада округу Хемпшир очікувала, що населення міста зросте приблизно ще на два відсотки між 2006 і 2013 роками, додавши ще близько 4200 до загальної кількості жителів. Найбільший приріст очікується серед людей похилого віку.',
#    'id': '12173',
#    'question': 'Яке єдине місто в Англії, крім Портсмута, є більш густонаселеним, ніж Саутгемптон?'}},
#  {'predicted': ('',
#    0.580305278301239,
#    'Корупція сприяє знищенню довкілля. Хоча корумповані суспільства можуть мати офіційне законодавство щодо захисту навколишнього середовища, воно може бути не виконане, якщо чиновників легко підкупити. Те саме стосується захисту працівників соціальних прав, запобігання профспілкам та дитячої праці. Порушення цих законів дозволяє корумпованим країнам отримати нелегітимну економічну перевагу на міжнародному ринку.'),
#   'truth': {'answers': {'text': ['дотримання будівельних, екологічних чи інших нормативних актів'],
#     'answer_start': [357]},
#    'context': 'Корупція також породжує економічні викривлення в державному секторі, перенаправляючи державні інвестиції на капітальні проекти, де хабарі та відкати є більшими. Посадові особи можуть збільшити технічну складність проектів державного сектору, щоб приховати або прокласти шлях для таких угод, тим самим ще більше спотворюючи інвестиції. Корупція також знижує дотримання будівельних, екологічних чи інших нормативних актів, знижує якість державних послуг та інфраструктури та збільшує бюджетний тиск на уряд.',
#    'id': '11195',
#    'question': 'Що може зменшити корупція за екологічними нормами?'}},
#  {'predicted': ('',
#    0.9915785193443298,
#    'До 1966 року на острові існувала монокультура, заснована на вирощуванні та переробці новозеландського льону для мотузки та ниток. Економіка Святої Єлени зараз слабка і майже повністю підтримується британським урядом. Державний сектор домінує в економіці, складаючи близько 50% валового внутрішнього продукту. У 2005 р. інфляція становила 4%. Відбулось зростання вартості палива, енергії та всіх імпортних товарів.'),
#   'truth': {'answers': {'text': [], 'answer_start': []},
#    'context': "У 1950-х роках Льюїс Бінфорд припустив, що ранні люди здобували м'ясо знаходженням мертв'ятини, а не полюванням. Люди в Ранньому Палеоліті жили в лісах і лісній місцевості, що дозволяло їм знаходити не тільки мертв'ятину, а й морепродукти, яйця, горіхи та фрукти. Замість того, щоб вбивати великих тварин на м’ясо, вони споживали туші таких тварин, які або були вбиті хижаками, або загинули від природних явищ. Археологічні та генетичні дані свідчать про те, що вихідні популяції мисливців-збирачів палеоліту вижили в малолісистих районах і розпорошились по ділянках з високою первинною продуктивністю, уникаючи густого лісу.",
#    'id': '4296',
#    'question': 'Які популяції розповсюдились районами з низькою первинною продукцією?'}},
#  {'predicted': ('',
#    0.9872025847434998,
#    "Бібліотека розташована на двох загальнодоступних платформах: Читальня в штаб-квартирі RIBA, 66 Портленд Плейс, Лондон; та приміщення для вивчення архітектури RIBA у крилі Генрі Коула V&A. Читальний зал, спроектований архітектором будівлі Джорджем Грей Ворнумом та його дружиною Міріам, зберігає оригінальний інтер’єр у стилі арт-деко 1934 року з відкритими книжковими полицями, оригінальними меблями та центральним простором з подвійною висотою. Навчальні кімнати, відкриті в 2004 році, були спроектовані компанією Wright & Wright. Бібліотека повністю фінансується RIBA, але вона відкрита для відвідувачів безкоштовно. Вона забезпечує безкоштовну освітню програму, спрямовану на студентів, освітні групи та сім'ї, а також інформаційну службу для членів RIBA та громадськості через Інформаційний центр RIBA.\ufeff"),
#   'truth': {'answers': {'text': [], 'answer_start': []},
#    'context': "У 2004 році обидві установи створили Архітектурну галерею (кімната 128) у V&A, де демонструються артефакти з колекцій обох установ, це перша перманентна галерея, присвячена архітектурі у Великобританії. Сусідній виставковий архітектурний простір (Кімната 128а) використовується для тимчасових демонстрацій, пов'язаних з архітектурою. Обидва простори були спроектовані архітектором Гаретом Хоскінсом. Одночасно колекції бібліотек малюнків та архівів RIBA переїхали з 21 Portman Place до нових приміщень у крилі Генрі Коула у V&A. У рамках Партнерства було відкрито нові навчальні кабінети, де представники громадськості могли переглядати предмети архітектурних колекцій RIBA та V&A під наглядом кураторського персоналу. Ці та сусідню навчальну кімнату спроектували архітектори Wright & Wright.",
#    'id': '8677',
#    'question': 'Чого немає в кімнаті 128а Музею Вікторії та Альберта?'}},
#  {'predicted': ('Плімутський аеропорт',
#    0.28941071033477783,
#    'Плімутський аеропорт розташований приблизно в 6 км від центру міста на півночі. В аеропорті була місцева авіакомпанія Air Southwest, яка відповідала за рейси через Великобританію та Ірландію. У червні 2003 року був опублікований звіт Південно-Західної АРР, що розглядав майбутнє авіації на південному заході та можливе закриття аеропортів. Згідно зі звітом, був зроблений висновок, що найкращим варіантом для південного заходу було закрити аеропорт Плімута та розширити міжнародний аеропорт Ексетер та Ньюквей Корнуолл, хоча, з іншого боку, була думка, що це не найкращий варіант для міста. У квітні 2011 року було оголошено про закриття аеропорту, що і було зроблено вже 23 грудня. Однак FlyPlymouth планує знову відкрити міський аеропорт до 2018 року, який надаватиме щоденні послуги в різних напрямках, включаючи Лондон.'),
#   'truth': {'answers': {'text': ['Міжнародний аеропорт Ченду Шуанлю'],
#     'answer_start': [298]},
#    'context': 'Офісні будівлі у фінансовому районі Шанхаю, включаючи вежу Цзінь Мао та Гонконгську башту Новий Світ, були евакуйовані. Адміністратор готелю "Тибет" в Ченду заявив, що після "евакуації гостей" все було "спокійно". Тим часом працівників заводу Ford у провінції Сичуань евакуювали близько 10 хвилин. Міжнародний аеропорт Ченду Шуанлю був закритий, а диспетчерська вежа та регіональний радіолокаційний контроль евакуйовані. В результаті один рейс SilkAir був перенаправлений і приземлився у Куньміні. Cathay Pacific затримав обидва напрями свого чотириразового щоденного маршруту Гонконг-Лондон через порушення роботи повітряного руху. Аеропорт Ченду Шуанглю знову відкрився пізніше ввечері 12 травня, пропонуючи обмежені послуги, оскільки аеропорт почав використовуватися як площадка для проведення операцій з надання допомоги.',
#    'id': '11247',
#    'question': 'Який аеропорт був закритий?'}},
#  {'predicted': (' до Кейптауна.',
#    0.6561859846115112,
#    'Медичне обслуговування фінансується урядом і здійснюється одним лікарем-резидентом з Південної Африки і п\'ятьма медсестрами, тому можливості для проведення хірургічних операцій або складних пологів обмежені. В екстрених випадках може знадобитися зв\'язок з риболовецькими судами,  щоб постраждала людина була переправлена до Кейптауна. Наприкінці 2007 року IBM та Beacon Equity Partners, співпрацюючи з Medweb, Медичним центром Університету Пітсбурга та урядом острова щодо "Проекту Трістан", надали лікареві острова доступ до телемедичної допомоги на далекі відстані, завдяки чому можна надсилати ЕКГ та рентгенівські знімки лікарям інших країн для негайної консультації. Ця система була обмежена через низьку надійність інтернет-з\'єднань та відсутність кваліфікованих технічних працівників на острові для обслуговування волоконно-оптичних зв\'язків між лікарнею та Інтернет-центром в адміністративних будівлях.'),
#   'truth': {'answers': {'text': ['національний архівний центр'],
#     'answer_start': [15]},
#    'context': 'Вашингтонський національний архівний центр (WNRC), розташований у місті Сайтленд, штат Меріленд, - це великий заклад, в якому зберігаються федеральні записи, які все ще перебувають під контролем агентства, що їх створює. Державні органи платять щорічну плату за зберігання там інформації. Відповідно до федеральних графіків ведення документації, документи в WNRC передаються на законне зберігання Національному архіву через певний момент (зазвичай це передбачає перенесення записів у Колледж-Парк). Тимчасові записи в WNRC зберігаються або платно, або знищуються після закінчення часу зберігання. WNRC також пропонує дослідницькі послуги та утримує невелику дослідницьку кімнату.',
#    'id': '8867',
#    'question': 'куди переносяться записи після перебування в WNRC?'}},
#  {'predicted': (' династії Мін,',
#    0.4858357012271881,
#    "Нанкін, одне з найважливіших міст країни протягом більше тисячі років, був визнаний однією з чотирьох великих стародавніх столиць Китаю. Протягом сотень років він був найбільшим містом в світі в цілому, користувався миром і процвітанням і був джерелом воєн і катастроф. Нанкін був столицею Східної Ву, однієї з трьох великих держав періоду трьох королівств (211-280), Східної Цзінь і кожної з Південних династій (Лю Сун, Південна Ци, Лянь і Чень), які послідовно правили Південним Китаєм з 317-589; Південної Тан, однієї з десяти держав (937-76); династії Мін, коли вперше усім Китаєм управляли з міста (1368-1421), та Китайської Республіки (1927–37, 1945–49) до її втечі на Тайвань під час громадянської війни в Китаї. Місто також служило місцем повстанського Тайпінського Небесного Королівства (1851–64) та японського маріонеткового режиму Ван Цзінвей (1940–45) під час Другої китайсько-японської війни, і зазнало жахливих звірств в обох конфліктах, включаючи Нанкінську різанину. Після створення Китаю Нанкін був столицею провінції Цзянсу і досі є номінальною столицею Китайської Республіки, де розміщуються багато важливих об'єктів спадщини, включаючи Президентський палац та мавзолей Сунь Ятсен. Нанкін славиться історичними пейзажами, горами та водами, такими як Фузіао, палац Мін, палац Чаотіан, порцеляновою вежею, барабанною вежею, кам'яним містом, міською стіною, річкою Ціньхуай, озером Сюаньву та фіолетовою горою. Серед ключових культурних закладів - Нанкінська бібліотека, Нанкінський музей та Художній музей."),
#   'truth': {'answers': {'text': ['під час династії Сун'],
#     'answer_start': [530]},
#    'context': 'Місто Нанкін було зруйновано після того, як династія Суй захопила його. Воно було перейменоване в Шенчжоу (昇 州) в династії Тан. Назву Нанкін реанімовано під час правління пізньої династії Тан. Місто було обрано столицею і назване Цзіньлін (金陵) під час правління Південного Тану (937–976), держави, яка стала наступником держави Ву. За часів її правління місто було перейменовано в Цзяннин (江寧) в династії Північної Сун і перейменоване в Цзянкан за Південної династії Сун. Текстильна промисловість Цзянканга збурилась і процвітала під час династії Сун, незважаючи на постійну загрозу іноземних вторгнень з півночі династією Цзінь під проводом Юрчен. Колись в місті знаходився двір Да Чу, недовговічна маріонеткова держава, заснована чжурчженями, і двір Сун. Династія Сун була в кінцевому підсумку винищена монголами. Під час правління династії Юань статус міста як центру текстильної промисловості ще більше зміцнився.',
#    'id': '9440',
#    'question': 'За якої династії Нанкін став процвітаючим текстильним містом?'}},
#  {'predicted': (' Мерая Кері, Кіт Урбан та Нікі Мінаж.',
#    0.14534974098205566,
#    'Прем’єра 12 сезону відбулася 16 січня 2013 року. Судді Дженніфер Лопес та Стівен Тайлер покинули шоу після двох сезонів. Саме тому цього року суддівська колегія була представлена у такому складі: Ренді Джексон, Мерая Кері, Кіт Урбан та Нікі Мінаж. Вперше після дев’ятого сезону до складу "комісії" знову входили не три, а чотири судді. Серед передсезонного галасу та ранніх епізодів шоу явно вирізнялося популярністю відео з сутичкою між суддями Мінаж та Кері. Відео з їх сваркою потрапило до мережі та було доступним на сайті TMZ.'),
#   'truth': {'answers': {'text': ['Вільям Ханг'], 'answer_start': [106]},
#    'context': 'Прем\'єра третього сезону відбулася 19 січня 2004 р. Одним з найбільш обговорюваних учасників конкурсу був Вільям Ханг, чиє фальшиве виконання "She Bangs" Рікі Мартіна здобуло значну увагу. Його поява на "Idol" принесла йому угоду на запис, і несподівано він став третім найбільш популярним співаком з того сезону.',
#    'id': '746',
#    'question': 'Хто з учасників був третім у продажу з третього сезону?'}},
#  {'predicted': ('',
#    0.9839679598808289,
#    'У березні 2006 року архівіст Сполучених Штатів на громадських слуханнях виявив, що існує меморандум про взаєморозуміння між NARA та різними урядовими установами для "перекласифікації", тобто вилучення з громадського доступу певних документів на благо національної безпеки, і роблячи це таким чином, щоб дослідники не мали змоги виявити процес (програма рекласифікації США). Перевірка показала, що більше однієї третини, вилученої з 1999 року, не містило конфіденційної інформації. Спочатку планувалося закінчити програму в 2007 році.'),
#   'truth': {'answers': {'text': ['закритих руїн округу Бейчуань'],
#     'answer_start': [154]},
#    'context': "12 травня 2009 року Китай відзначив першу річницю землетрусу хвилиною мовчання, коли люди по всій країні згадували загиблих. Уряд також відкрив доступ до закритих руїн округу Бейчуань на три дні, після чого він буде заморножений як державний музей пам'яток землетрусів, щоб нагадати людям про страшну катастрофу. Також було проведено кілька концертів по всій країні для збору грошей для тих, хто вижив після землетрусу.",
#    'id': '12568',
#    'question': 'Куди уряд відкрив доступ?'}},
#  {'predicted': ('',
#    0.9767404198646545,
#    'Формати спеціалізованих періодичних коміксів дуже різняться в різних культурах. Комікси, насамперед американського формату, - це тонкі періодичні видання, які зазвичай видаються у кольорі. Європейські та японські комікси часто видають серіями в журналах - щомісяця або щотижня в Європі, і, як правило, чорно-білі та щотижня в Японії. Японський журнал коміксів, як правило, охоплює сотні сторінок.'),
#   'truth': {'answers': {'text': [], 'answer_start': []},
#    'context': 'Формати спеціалізованих періодичних коміксів дуже різняться в різних культурах. Комікси, насамперед американського формату, - це тонкі періодичні видання, які зазвичай видаються у кольорі. Європейські та японські комікси часто видають серіями в журналах - щомісяця або щотижня в Європі, і, як правило, чорно-білі та щотижня в Японії. Японський журнал коміксів, як правило, охоплює сотні сторінок.',
#    'id': '5046',
#    'question': 'Де зазвичай з’являються несеріалізовані комікси в Японії?'}},
#  {'predicted': ('',
#    0.9861445426940918,
#    'Зразки ДНК від 1228 росіян показують, що аналізовані Y-хромосоми всі, крім 20 (1,6%), потрапляють у сім основних гаплогруп, характерних для популяцій Західної Євразії. У сукупності вони становлять 95% усього російського Y-хромосомного пулу. Лише (0,7%) потрапили до гаплогруп, характерних для населення Східної та Південної Азії. Мітохондріальна ДНК (mtDNA), досліджена у поляків та росіян, виявила наявність усіх основних європейських гаплогруп, які характеризувались подібними схемами розподілу у поляків та росіян. Аналіз ДНК не виявив жодних конкретних комбінацій унікальних гаплотипів мтДНК та їх субкластерів. ДНК чітко показує, що і поляки, і росіяни не відрізняються від сусідніх європейських груп.'),
#   'truth': {'answers': {'text': [], 'answer_start': []},
#    'context': "З іншого боку, I2a1b1 (P41.2) є типовим для південнослов’янського населення, найвищий у Боснії та Герцеговині (> 50%). Гаплогрупу I2a2 також часто зустрічають у північно-східних італійців. Також висока концентрація I2a2a в молдавському регіоні Румунії, Молдови та західної України. Згідно з оригінальними дослідженнями, Hg I2a2, як вважалося, виник на західних Балканах десь після ЛГМ, згодом поширившись із Балкан через Центральноросійську рівнину. Нещодавно Кен Нордтведт розділив I2a2 на дві клади - N (північну) та S (південну), щодо того, де вони виникли порівняно з річкою Дунай. Він припускає, що N трохи старший за S. Він перерахував вік I2a2 до ~ 2550 років і запропонував, щоб нинішній розподіл пояснювався експансією слов'ян з району на північний схід від Карпат.",
#    'id': '11894',
#    'question': 'Що передувало l2a1b1?'}},
#  {'predicted': ('',
#    0.8960049748420715,
#    'Показник щільності населення, який зазвичай повідомляють для Оклахоми-Сіті, використовує площу по кордону міста і може дещо ввести в оману. Урбанізовані райони Оклахоми займають приблизно 244 квадратних миль (630 км2), що призводить до щільності у 2500 людей на квадратну милю (2013 р.). Для порівняння, сільські водозбірні райони охоплюють решту 377 квадратних миль (980 км2) території міста.'),
#   'truth': {'answers': {'text': ['34'], 'answer_start': [192]},
#    'context': 'Основні телерадіомовні мережі США мають філії на ринку Оклахоми-Сіті, що посідають 41-е місце за рейтингом Нільсена у телебаченні та 48-е місце за рейтингом радіо Arbitron. Ці філії охоплюють 34 округи, що обслуговують центральні, північно-центральні та західно-центральні райони Оклахоми. На ринку також є кілька релігійних станцій, включаючи канал KTBO-TV, що належить і управляється TBN, і канал KOCM, що належить і управляється нормандською компанією Daystar.',
#    'id': '4239',
#    'question': 'Скільки округів охоплює мережа міст Оклахоми?'}}]

# %% [markdown]
# `eval_odqa()` порівнює правильну відповідь лише з найімовірнішою передбаченою, що є справедливим підходом: користувачам важливо отримувати правильний результат на першій позиції. Водночас, важливу роль у оцінюванні пошукових систем можуть відігравати і метрики, що враховують не лише першу позицію, а N передбачень з найбільшими ймовірностями. Наприклад, для двох рішень з приблизно однаковими результатами додаткова оцінка потрапляння правильної відповіді у топ-5 передбачень допоможе визначити рішення з кращою узагальнюючою здібністю.
#
# **Завдання**: модифікуйте функцію `eval_odqa()` так, щоб вона зараховувала правильну відповідь у випадку її знаходження у топ-N (за ймовірністю) передбаченнях. Проведіть повторну оцінку реалізованого рішення та порівняйте результати.
#
# Варіант = Номер_у_списку % 4 + 1
#
# |**Варіант**| N |
# |-----------|---|
# |**1**      | 3 |
# |**2**      | 5 |
# |**3**      | 7 |
# |**4**      | 10|

# %%
def eval_odqa_first_n(ranker, reader, test_set, k=10, handle_impossible_answer=True, threshold=0.5, top_n=5):
    raise NotImplementedError
